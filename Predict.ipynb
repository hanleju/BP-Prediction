# %% [markdown]
# ## GradientBoostingRegressor

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingRegressor, VotingRegressor
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler
import numpy as np
import matplotlib.pyplot as plt
import optuna

# %% [markdown]
# ### Data

# %%
file_path = 'Data.csv'
cleaned_data = pd.read_csv(file_path, encoding='euc-kr')

features_encoded = cleaned_data.drop(['dbp', 'sbp'],axis=1)
targets_encoded = cleaned_data[['dbp', 'sbp']].reset_index(drop=True)

X_train_encoded, X_test_encoded, y_train, y_test = train_test_split(features_encoded, targets_encoded, test_size=0.2, random_state=42)

scaler = StandardScaler()
X_train_encoded = scaler.fit_transform(X_train_encoded)
X_test_encoded = scaler.transform(X_test_encoded)


y_train_dbp = y_train.iloc[:, 0]  # DBP
y_train_sbp = y_train.iloc[:, 1]  # SBP

# %% [markdown]
# ### GradientBoostingRegressor + Bayesian Optimizer

# %%
def objective(trial, X_train, y_train, X_test, y_test):
   
    n_estimators = trial.suggest_int('n_estimators', 1000, 5000)
    learning_rate = trial.suggest_float('learning_rate', 0.001, 0.1, log=True)
    max_depth = trial.suggest_int('max_depth', 3, 30)

    model = GradientBoostingRegressor(n_estimators=n_estimators,
                                      learning_rate=learning_rate,
                                      max_depth=max_depth,
                                      random_state=2,
                                      loss='absolute_error')
    model.fit(X_train, y_train)
    preds = model.predict(X_test)
    mse = mean_squared_error(y_test, preds)
    
    return mse

def optimize_hyperparameters(X_train, y_train, X_test, y_test):
    study = optuna.create_study(direction='minimize')
    study.optimize(lambda trial: objective(trial, X_train, y_train, X_test, y_test), n_trials=40)
    return study.best_params

# %% [markdown]
# #### DBP

# %%
y_test_dbp = y_test.iloc[:, 0] # DBP

best_params_dbp = optimize_hyperparameters(X_train_encoded, y_train_dbp, X_test_encoded, y_test_dbp)
print("Best parameters for DBP:", best_params_dbp)

model_dbp = GradientBoostingRegressor(**best_params_dbp, random_state=2, loss='absolute_error')
model_dbp.fit(X_train_encoded, y_train_dbp)
y_dbp_pred = model_dbp.predict(X_test_encoded)

mse_dbp = mean_squared_error(y_test_dbp, y_dbp_pred)
rmse_dbp = np.sqrt(mse_dbp)
print("DBP Mean Squared Error (MSE):", mse_dbp)
print("DBP Root Mean Squared Error (RMSE):", rmse_dbp)
# Out:
# [I 2024-02-07 14:06:06,000] A new study created in memory with name: no-name-a32b4c39-7370-4c14-9a68-45a1f1c7865f
# [I 2024-02-07 14:06:11,329] Trial 0 finished with value: 82.87296029508062 and parameters: {'n_estimators': 4016, 'learning_rate': 0.01940381143448357, 'max_depth': 4}. Best is trial 0 with value: 82.87296029508062.
# [I 2024-02-07 14:06:21,766] Trial 1 finished with value: 75.67408045031853 and parameters: {'n_estimators': 3999, 'learning_rate': 0.002470719890211436, 'max_depth': 17}. Best is trial 1 with value: 75.67408045031853.
# [I 2024-02-07 14:06:30,169] Trial 2 finished with value: 75.89189224464172 and parameters: {'n_estimators': 3225, 'learning_rate': 0.028471663735204662, 'max_depth': 22}. Best is trial 1 with value: 75.67408045031853.
# [I 2024-02-07 14:06:40,171] Trial 3 finished with value: 78.14838917543189 and parameters: {'n_estimators': 3893, 'learning_rate': 0.01716691743996452, 'max_depth': 11}. Best is trial 1 with value: 75.67408045031853.
# [I 2024-02-07 14:06:45,579] Trial 4 finished with value: 69.59213652136782 and parameters: {'n_estimators': 2032, 'learning_rate': 0.004566905784567514, 'max_depth': 17}. Best is trial 4 with value: 69.59213652136782.
# [I 2024-02-07 14:06:51,331] Trial 5 finished with value: 67.26427661320277 and parameters: {'n_estimators': 2041, 'learning_rate': 0.001454655094024557, 'max_depth': 29}. Best is trial 5 with value: 67.26427661320277.
# [I 2024-02-07 14:07:04,105] Trial 6 finished with value: 75.99889386274043 and parameters: {'n_estimators': 4907, 'learning_rate': 0.01954183302140197, 'max_depth': 24}. Best is trial 5 with value: 67.26427661320277.
# [I 2024-02-07 14:07:09,593] Trial 7 finished with value: 78.80594372245069 and parameters: {'n_estimators': 2038, 'learning_rate': 0.05291383224223121, 'max_depth': 28}. Best is trial 5 with value: 67.26427661320277.
# [I 2024-02-07 14:07:15,532] Trial 8 finished with value: 81.17726273177055 and parameters: {'n_estimators': 2246, 'learning_rate': 0.05046116743720855, 'max_depth': 20}. Best is trial 5 with value: 67.26427661320277.
# [I 2024-02-07 14:07:23,844] Trial 9 finished with value: 68.47654126634649 and parameters: {'n_estimators': 3121, 'learning_rate': 0.0038729856102562568, 'max_depth': 27}. Best is trial 5 with value: 67.26427661320277.
# [I 2024-02-07 14:07:26,811] Trial 10 finished with value: 70.43315868334427 and parameters: {'n_estimators': 1034, 'learning_rate': 0.001037559776779386, 'max_depth': 30}. Best is trial 5 with value: 67.26427661320277.
# [I 2024-02-07 14:07:33,928] Trial 11 finished with value: 71.90249700846532 and parameters: {'n_estimators': 2807, 'learning_rate': 0.004472172599335433, 'max_depth': 26}. Best is trial 5 with value: 67.26427661320277.
# [I 2024-02-07 14:07:37,867] Trial 12 finished with value: 69.22755496776347 and parameters: {'n_estimators': 1369, 'learning_rate': 0.0013480218313064469, 'max_depth': 30}. Best is trial 5 with value: 67.26427661320277.
# [I 2024-02-07 14:07:45,745] Trial 13 finished with value: 74.09137804140987 and parameters: {'n_estimators': 2922, 'learning_rate': 0.006074444372099523, 'max_depth': 24}. Best is trial 5 with value: 67.26427661320277.
# [I 2024-02-07 14:07:51,958] Trial 14 finished with value: 72.63071522295164 and parameters: {'n_estimators': 2460, 'learning_rate': 0.00230219468938279, 'max_depth': 9}. Best is trial 5 with value: 67.26427661320277.
# [I 2024-02-07 14:08:01,466] Trial 15 finished with value: 74.20388164867744 and parameters: {'n_estimators': 3401, 'learning_rate': 0.0022216726371853696, 'max_depth': 20}. Best is trial 5 with value: 67.26427661320277.
# [I 2024-02-07 14:08:05,886] Trial 16 finished with value: 74.56629867732097 and parameters: {'n_estimators': 1634, 'learning_rate': 0.00817176567263622, 'max_depth': 27}. Best is trial 5 with value: 67.26427661320277.
# [I 2024-02-07 14:08:13,012] Trial 17 finished with value: 71.86921445970958 and parameters: {'n_estimators': 2605, 'learning_rate': 0.003349047129378479, 'max_depth': 13}. Best is trial 5 with value: 67.26427661320277.
# [I 2024-02-07 14:08:22,899] Trial 18 finished with value: 70.24177818085133 and parameters: {'n_estimators': 3566, 'learning_rate': 0.0015293049413950045, 'max_depth': 25}. Best is trial 5 with value: 67.26427661320277.
# [I 2024-02-07 14:08:34,948] Trial 19 finished with value: 79.32605971205898 and parameters: {'n_estimators': 4568, 'learning_rate': 0.011631618178319177, 'max_depth': 21}. Best is trial 5 with value: 67.26427661320277.
# [I 2024-02-07 14:08:39,666] Trial 20 finished with value: 67.62811627776766 and parameters: {'n_estimators': 1665, 'learning_rate': 0.0015685653875578667, 'max_depth': 28}. Best is trial 5 with value: 67.26427661320277.
# [I 2024-02-07 14:08:44,552] Trial 21 finished with value: 68.40357261129054 and parameters: {'n_estimators': 1711, 'learning_rate': 0.001498082599310994, 'max_depth': 30}. Best is trial 5 with value: 67.26427661320277.
# [I 2024-02-07 14:08:49,373] Trial 22 finished with value: 67.14308518720942 and parameters: {'n_estimators': 1714, 'learning_rate': 0.00159788836584835, 'max_depth': 30}. Best is trial 22 with value: 67.14308518720942.
# [I 2024-02-07 14:08:52,488] Trial 23 finished with value: 70.69011909057605 and parameters: {'n_estimators': 1080, 'learning_rate': 0.0010105074405445137, 'max_depth': 28}. Best is trial 22 with value: 67.14308518720942.
# [I 2024-02-07 14:08:56,988] Trial 24 finished with value: 72.00191007262667 and parameters: {'n_estimators': 1648, 'learning_rate': 0.09838453065291303, 'max_depth': 24}. Best is trial 22 with value: 67.14308518720942.
# [I 2024-02-07 14:09:02,506] Trial 25 finished with value: 70.42421202129815 and parameters: {'n_estimators': 1920, 'learning_rate': 0.0018274271071200383, 'max_depth': 30}. Best is trial 22 with value: 67.14308518720942.
# [I 2024-02-07 14:09:06,857] Trial 26 finished with value: 72.01248391072322 and parameters: {'n_estimators': 1410, 'learning_rate': 0.0029482105394605736, 'max_depth': 22}. Best is trial 22 with value: 67.14308518720942.
# [I 2024-02-07 14:09:13,326] Trial 27 finished with value: 76.07341607489822 and parameters: {'n_estimators': 2441, 'learning_rate': 0.006510366630647965, 'max_depth': 28}. Best is trial 22 with value: 67.14308518720942.
# [I 2024-02-07 14:09:14,864] Trial 28 finished with value: 75.11550380411204 and parameters: {'n_estimators': 1419, 'learning_rate': 0.0018950920509100495, 'max_depth': 3}. Best is trial 22 with value: 67.14308518720942.
# [I 2024-02-07 14:09:20,480] Trial 29 finished with value: 70.64291115621761 and parameters: {'n_estimators': 2235, 'learning_rate': 0.0012627208604190628, 'max_depth': 8}. Best is trial 22 with value: 67.14308518720942.
# [I 2024-02-07 14:09:25,794] Trial 30 finished with value: 75.09553061097047 and parameters: {'n_estimators': 1944, 'learning_rate': 0.0028725445373767432, 'max_depth': 19}. Best is trial 22 with value: 67.14308518720942.
# [I 2024-02-07 14:09:30,661] Trial 31 finished with value: 68.58546631619002 and parameters: {'n_estimators': 1659, 'learning_rate': 0.001612692527640723, 'max_depth': 30}. Best is trial 22 with value: 67.14308518720942.
# [I 2024-02-07 14:09:35,630] Trial 32 finished with value: 69.24343185714575 and parameters: {'n_estimators': 1717, 'learning_rate': 0.0013260111732646305, 'max_depth': 28}. Best is trial 22 with value: 67.14308518720942.
# [I 2024-02-07 14:09:39,218] Trial 33 finished with value: 68.87574769541976 and parameters: {'n_estimators': 1259, 'learning_rate': 0.0021393784076967717, 'max_depth': 26}. Best is trial 22 with value: 67.14308518720942.
# [I 2024-02-07 14:09:45,610] Trial 34 finished with value: 69.56107294149994 and parameters: {'n_estimators': 2220, 'learning_rate': 0.0010053149743538506, 'max_depth': 29}. Best is trial 22 with value: 67.14308518720942.
# [I 2024-02-07 14:09:50,667] Trial 35 finished with value: 70.94559457948084 and parameters: {'n_estimators': 1822, 'learning_rate': 0.002631603265722547, 'max_depth': 15}. Best is trial 22 with value: 67.14308518720942.
# [I 2024-02-07 14:09:58,347] Trial 36 finished with value: 67.43723942712067 and parameters: {'n_estimators': 2686, 'learning_rate': 0.0018769440775509728, 'max_depth': 26}. Best is trial 22 with value: 67.14308518720942.
# [I 2024-02-07 14:10:05,246] Trial 37 finished with value: 75.92454449093933 and parameters: {'n_estimators': 2620, 'learning_rate': 0.005099268127452432, 'max_depth': 23}. Best is trial 22 with value: 67.14308518720942.
# [I 2024-02-07 14:10:10,916] Trial 38 finished with value: 69.69343624702675 and parameters: {'n_estimators': 2111, 'learning_rate': 0.003343118587331423, 'max_depth': 26}. Best is trial 22 with value: 67.14308518720942.
# [I 2024-02-07 14:10:18,081] Trial 39 finished with value: 74.46054312921086 and parameters: {'n_estimators': 2416, 'learning_rate': 0.0019056276750197504, 'max_depth': 18}. Best is trial 22 with value: 67.14308518720942.
# Best parameters for DBP: {'n_estimators': 1714, 'learning_rate': 0.00159788836584835, 'max_depth': 30}
# DBP Mean Squared Error (MSE): 67.14308518720942
# DBP Root Mean Squared Error (RMSE): 8.1940884293013

# %% [markdown]
# #### SBP

# %%
y_test_sbp = y_test.iloc[:, 1] # SBP

best_params_sbp = optimize_hyperparameters(X_train_encoded, y_train_sbp, X_test_encoded, y_test_sbp)
print("Best parameters for SBP:", best_params_sbp)

model_sbp = GradientBoostingRegressor(**best_params_sbp, random_state=2, loss='absolute_error')
model_sbp.fit(X_train_encoded, y_train_sbp)
y_sbp_pred = model_sbp.predict(X_test_encoded)

mse_sbp = mean_squared_error(y_test_sbp, y_sbp_pred)
rmse_sbp = np.sqrt(mse_sbp)
print("SBP Mean Squared Error (MSE):", mse_sbp)
print("SBP Root Mean Squared Error (RMSE):", rmse_sbp)
# Out:
# [I 2024-02-07 14:10:23,074] A new study created in memory with name: no-name-5276b5bc-613a-431c-8623-a5aaee51fc73
# [I 2024-02-07 14:10:27,969] Trial 0 finished with value: 142.67580100877402 and parameters: {'n_estimators': 1910, 'learning_rate': 0.0015047650151175367, 'max_depth': 9}. Best is trial 0 with value: 142.67580100877402.
# [I 2024-02-07 14:10:37,801] Trial 1 finished with value: 138.92129903762756 and parameters: {'n_estimators': 4849, 'learning_rate': 0.011816365324514237, 'max_depth': 6}. Best is trial 1 with value: 138.92129903762756.
# [I 2024-02-07 14:10:42,260] Trial 2 finished with value: 140.74400915704499 and parameters: {'n_estimators': 1793, 'learning_rate': 0.0021589520226932136, 'max_depth': 19}. Best is trial 1 with value: 138.92129903762756.
# [I 2024-02-07 14:10:52,604] Trial 3 finished with value: 149.82937590009018 and parameters: {'n_estimators': 4331, 'learning_rate': 0.06327276755422695, 'max_depth': 21}. Best is trial 1 with value: 138.92129903762756.
# [I 2024-02-07 14:11:01,277] Trial 4 finished with value: 135.54478702482018 and parameters: {'n_estimators': 3680, 'learning_rate': 0.004007027276149274, 'max_depth': 8}. Best is trial 4 with value: 135.54478702482018.
# [I 2024-02-07 14:11:08,930] Trial 5 finished with value: 142.72969843331967 and parameters: {'n_estimators': 2889, 'learning_rate': 0.04965373451363637, 'max_depth': 30}. Best is trial 4 with value: 135.54478702482018.
# [I 2024-02-07 14:11:20,870] Trial 6 finished with value: 139.86369839113397 and parameters: {'n_estimators': 4703, 'learning_rate': 0.01158308983659986, 'max_depth': 25}. Best is trial 4 with value: 135.54478702482018.
# [I 2024-02-07 14:11:28,233] Trial 7 finished with value: 140.20035744338784 and parameters: {'n_estimators': 2882, 'learning_rate': 0.022176606535099747, 'max_depth': 25}. Best is trial 4 with value: 135.54478702482018.
# [I 2024-02-07 14:11:36,274] Trial 8 finished with value: 134.97677214681224 and parameters: {'n_estimators': 3046, 'learning_rate': 0.043984528459966185, 'max_depth': 12}. Best is trial 8 with value: 134.97677214681224.
# [I 2024-02-07 14:11:38,175] Trial 9 finished with value: 133.60605834666364 and parameters: {'n_estimators': 1866, 'learning_rate': 0.004068064283970813, 'max_depth': 3}. Best is trial 9 with value: 133.60605834666364.
# [I 2024-02-07 14:11:39,490] Trial 10 finished with value: 133.215114407472 and parameters: {'n_estimators': 1273, 'learning_rate': 0.0043884124438374646, 'max_depth': 3}. Best is trial 10 with value: 133.215114407472.
# [I 2024-02-07 14:11:40,994] Trial 11 finished with value: 132.75416619796547 and parameters: {'n_estimators': 1120, 'learning_rate': 0.004309217352256161, 'max_depth': 4}. Best is trial 11 with value: 132.75416619796547.
# [I 2024-02-07 14:11:44,102] Trial 12 finished with value: 134.51226135926495 and parameters: {'n_estimators': 1166, 'learning_rate': 0.004481783342190297, 'max_depth': 13}. Best is trial 11 with value: 132.75416619796547.
# [I 2024-02-07 14:11:45,157] Trial 13 finished with value: 132.55468745353116 and parameters: {'n_estimators': 1027, 'learning_rate': 0.006478643211574032, 'max_depth': 3}. Best is trial 13 with value: 132.55468745353116.
# [I 2024-02-07 14:11:47,691] Trial 14 finished with value: 131.37743467219104 and parameters: {'n_estimators': 1026, 'learning_rate': 0.007005656892776844, 'max_depth': 14}. Best is trial 14 with value: 131.37743467219104.
# [I 2024-02-07 14:11:53,763] Trial 15 finished with value: 140.3857650413986 and parameters: {'n_estimators': 2341, 'learning_rate': 0.0231238406691967, 'max_depth': 14}. Best is trial 14 with value: 131.37743467219104.
# [I 2024-02-07 14:11:57,389] Trial 16 finished with value: 130.90578508359476 and parameters: {'n_estimators': 1476, 'learning_rate': 0.007927793871164246, 'max_depth': 17}. Best is trial 16 with value: 130.90578508359476.
# [I 2024-02-07 14:12:03,250] Trial 17 finished with value: 133.436538617772 and parameters: {'n_estimators': 2318, 'learning_rate': 0.01884167663482511, 'max_depth': 17}. Best is trial 16 with value: 130.90578508359476.
# [I 2024-02-07 14:12:07,426] Trial 18 finished with value: 147.48481371152397 and parameters: {'n_estimators': 1577, 'learning_rate': 0.0010275986244435052, 'max_depth': 16}. Best is trial 16 with value: 130.90578508359476.
# [I 2024-02-07 14:12:13,374] Trial 19 finished with value: 138.66493144024602 and parameters: {'n_estimators': 2402, 'learning_rate': 0.008177359839597652, 'max_depth': 22}. Best is trial 16 with value: 130.90578508359476.
# [I 2024-02-07 14:12:17,456] Trial 20 finished with value: 169.82218024842797 and parameters: {'n_estimators': 1513, 'learning_rate': 0.09694509953045871, 'max_depth': 10}. Best is trial 16 with value: 130.90578508359476.
# [I 2024-02-07 14:12:20,187] Trial 21 finished with value: 143.97590545532566 and parameters: {'n_estimators': 1064, 'learning_rate': 0.008439401380946709, 'max_depth': 16}. Best is trial 16 with value: 130.90578508359476.
# [I 2024-02-07 14:12:23,751] Trial 22 finished with value: 133.61319107988024 and parameters: {'n_estimators': 1431, 'learning_rate': 0.00670097120664514, 'max_depth': 19}. Best is trial 16 with value: 130.90578508359476.
# [I 2024-02-07 14:12:28,830] Trial 23 finished with value: 136.42361634976712 and parameters: {'n_estimators': 2071, 'learning_rate': 0.002520824998239683, 'max_depth': 11}. Best is trial 16 with value: 130.90578508359476.
# [I 2024-02-07 14:12:32,049] Trial 24 finished with value: 133.88775627078323 and parameters: {'n_estimators': 1535, 'learning_rate': 0.015196811453702528, 'max_depth': 6}. Best is trial 16 with value: 130.90578508359476.
# [I 2024-02-07 14:12:34,685] Trial 25 finished with value: 141.28078898728677 and parameters: {'n_estimators': 1027, 'learning_rate': 0.006409906671048848, 'max_depth': 24}. Best is trial 16 with value: 130.90578508359476.
# [I 2024-02-07 14:12:44,053] Trial 26 finished with value: 132.71954520210292 and parameters: {'n_estimators': 3729, 'learning_rate': 0.002600259633272994, 'max_depth': 29}. Best is trial 16 with value: 130.90578508359476.
# [I 2024-02-07 14:12:48,465] Trial 27 finished with value: 136.45578498200737 and parameters: {'n_estimators': 1659, 'learning_rate': 0.006156727577694802, 'max_depth': 15}. Best is trial 16 with value: 130.90578508359476.
# [I 2024-02-07 14:12:52,089] Trial 28 finished with value: 137.2202207711081 and parameters: {'n_estimators': 1362, 'learning_rate': 0.03241161129340224, 'max_depth': 18}. Best is trial 16 with value: 130.90578508359476.
# [I 2024-02-07 14:12:57,134] Trial 29 finished with value: 135.9967644333525 and parameters: {'n_estimators': 2039, 'learning_rate': 0.015909687247386523, 'max_depth': 9}. Best is trial 16 with value: 130.90578508359476.
# [I 2024-02-07 14:13:02,526] Trial 30 finished with value: 137.93449546597773 and parameters: {'n_estimators': 2631, 'learning_rate': 0.0019435381639488689, 'max_depth': 6}. Best is trial 16 with value: 130.90578508359476.
# [I 2024-02-07 14:13:11,470] Trial 31 finished with value: 126.49989190354164 and parameters: {'n_estimators': 3488, 'learning_rate': 0.002810318368933869, 'max_depth': 29}. Best is trial 31 with value: 126.49989190354164.
# [I 2024-02-07 14:13:20,440] Trial 32 finished with value: 122.17498165299487 and parameters: {'n_estimators': 3376, 'learning_rate': 0.001284550259341372, 'max_depth': 28}. Best is trial 32 with value: 122.17498165299487.
# [I 2024-02-07 14:13:28,799] Trial 33 finished with value: 133.03027297915227 and parameters: {'n_estimators': 3379, 'learning_rate': 0.0012745441565369209, 'max_depth': 28}. Best is trial 32 with value: 122.17498165299487.
# [I 2024-02-07 14:13:39,330] Trial 34 finished with value: 138.4289759115443 and parameters: {'n_estimators': 4025, 'learning_rate': 0.0015491702095443793, 'max_depth': 27}. Best is trial 32 with value: 122.17498165299487.
# [I 2024-02-07 14:13:47,818] Trial 35 finished with value: 125.79498514714733 and parameters: {'n_estimators': 3385, 'learning_rate': 0.0031398505746715343, 'max_depth': 21}. Best is trial 32 with value: 122.17498165299487.
# [I 2024-02-07 14:13:56,308] Trial 36 finished with value: 132.40406747159645 and parameters: {'n_estimators': 3312, 'learning_rate': 0.0028559444356826714, 'max_depth': 21}. Best is trial 32 with value: 122.17498165299487.
# [I 2024-02-07 14:14:05,679] Trial 37 finished with value: 122.80625925888522 and parameters: {'n_estimators': 3653, 'learning_rate': 0.0031758657015803693, 'max_depth': 27}. Best is trial 32 with value: 122.17498165299487.
# [I 2024-02-07 14:14:15,590] Trial 38 finished with value: 136.69348162735992 and parameters: {'n_estimators': 4100, 'learning_rate': 0.0016702768634230113, 'max_depth': 27}. Best is trial 32 with value: 122.17498165299487.
# [I 2024-02-07 14:14:24,581] Trial 39 finished with value: 139.80874546408495 and parameters: {'n_estimators': 3571, 'learning_rate': 0.003454650356285763, 'max_depth': 30}. Best is trial 32 with value: 122.17498165299487.
# Best parameters for SBP: {'n_estimators': 3376, 'learning_rate': 0.001284550259341372, 'max_depth': 28}
# SBP Mean Squared Error (MSE): 122.17498165299487
# SBP Root Mean Squared Error (RMSE): 11.05327922622942

# %%
# DBP
plt.figure(figsize=(8,4))
plt.scatter(y_test_dbp, y_dbp_pred, color='blue')
plt.plot([y_test_dbp.min(), y_test_dbp.max()], [y_test_dbp.min(), y_test_dbp.max()], 'k--', lw=4)
plt.xlabel('Measured')
plt.ylabel('Predicted')
plt.title('Actual vs Predicted Values for DBP')
plt.show()

# SBP
plt.figure(figsize=(8,4))
plt.scatter(y_test_sbp, y_sbp_pred, color='red')
plt.plot([y_test_sbp.min(), y_test_sbp.max()], [y_test_sbp.min(), y_test_sbp.max()], 'k--', lw=4)
plt.xlabel('Measured')
plt.ylabel('Predicted')
plt.title('Actual vs Predicted Values for SBP')
plt.show()

# %% [markdown]
# #### K-FOLD cross validation

# %%
from sklearn.model_selection import KFold

k = 5
kf = KFold(n_splits=k, random_state=42, shuffle=True)

mse_scores_dbp = []
mse_scores_sbp = []

for train_index, test_index in kf.split(features_encoded):
    X_train, X_test = features_encoded.iloc[train_index], features_encoded.iloc[test_index]
    y_train, y_test = targets_encoded.iloc[train_index], targets_encoded.iloc[test_index]

    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    X_test_scaled = scaler.transform(X_test)

    y_train_dbp = y_train.iloc[:, 0]
    model_dbp = GradientBoostingRegressor(**best_params_dbp, random_state=42, loss='absolute_error')
    model_dbp.fit(X_train_scaled, y_train_dbp)
    y_dbp_pred = model_dbp.predict(X_test_scaled)
    mse_scores_dbp.append(mean_squared_error(y_test.iloc[:, 0], y_dbp_pred))

    y_train_sbp = y_train.iloc[:, 1]
    model_sbp = GradientBoostingRegressor(**best_params_sbp, random_state=42, loss='absolute_error')
    model_sbp.fit(X_train_scaled, y_train_sbp)
    y_sbp_pred = model_sbp.predict(X_test_scaled)
    mse_scores_sbp.append(mean_squared_error(y_test.iloc[:, 1], y_sbp_pred))

avg_mse_dbp = np.mean(mse_scores_dbp)
avg_rmse_dbp = np.sqrt(avg_mse_dbp)
avg_mse_sbp = np.mean(mse_scores_sbp)
avg_rmse_sbp = np.sqrt(avg_mse_sbp)

print(f"DBP 평균 MSE: {avg_mse_dbp}, 평균 RMSE: {avg_rmse_dbp}")
print(f"SBP 평균 MSE: {avg_mse_sbp}, 평균 RMSE: {avg_rmse_sbp}")
